# %%
import pandas as pd

# %%
file_path = f'../data/processed/cleaned_yield_curve_fred.csv'
df = pd.read_csv(file_path)
df
# Out:
#             date      1Y      2Y      5Y     10Y     30Y
# 0     2000-01-03  0.0609  0.0638  0.0650  0.0658  0.0661
# 1     2000-01-04  0.0600  0.0630  0.0640  0.0649  0.0653
# 2     2000-01-05  0.0605  0.0638  0.0651  0.0662  0.0664
# 3     2000-01-06  0.0603  0.0635  0.0646  0.0657  0.0658
# 4     2000-01-07  0.0600  0.0631  0.0642  0.0652  0.0655
# ...          ...     ...     ...     ...     ...     ...
# 6835  2026-03-16  0.0364  0.0368  0.0380  0.0423  0.0486
# 6836  2026-03-17  0.0363  0.0368  0.0379  0.0420  0.0485
# 6837  2026-03-18  0.0368  0.0376  0.0387  0.0426  0.0488
# 6838  2026-03-19  0.0373  0.0379  0.0388  0.0425  0.0483
# 6839  2026-03-20  0.0380  0.0388  0.0401  0.0439  0.0496
#
# [6840 rows x 6 columns]

# %%
df.iloc[-1]
# Out:
# date    2026-03-20
# 1Y           0.038
# 2Y          0.0388
# 5Y          0.0401
# 10Y         0.0439
# 30Y         0.0496
# Name: 6839, dtype: object
