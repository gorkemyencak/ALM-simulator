# %%
import pandas as pd

# %%
file_path = f'../data/raw/yield_curve_fred.csv'
df = pd.read_csv(file_path)
df
# Out:
#             date    1Y    2Y    5Y   10Y   30Y
# 0     2000-01-03  6.09  6.38  6.50  6.58  6.61
# 1     2000-01-04  6.00  6.30  6.40  6.49  6.53
# 2     2000-01-05  6.05  6.38  6.51  6.62  6.64
# 3     2000-01-06  6.03  6.35  6.46  6.57  6.58
# 4     2000-01-07  6.00  6.31  6.42  6.52  6.55
# ...          ...   ...   ...   ...   ...   ...
# 6835  2026-03-16  3.64  3.68  3.80  4.23  4.86
# 6836  2026-03-17  3.63  3.68  3.79  4.20  4.85
# 6837  2026-03-18  3.68  3.76  3.87  4.26  4.88
# 6838  2026-03-19  3.73  3.79  3.88  4.25  4.83
# 6839  2026-03-20  3.80  3.88  4.01  4.39  4.96
#
# [6840 rows x 6 columns]
